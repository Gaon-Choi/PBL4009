# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive/'
# Out:
# /content/drive/My Drive

# %%
# !mkdir 'pbl_ai'
# Out:
# mkdir: cannot create directory ‘pbl_ai’: File exists

# %%
cd 'pbl_ai'
# Out:
# /content/drive/MyDrive/pbl_ai

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12264, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 12264 (delta 18), reused 24 (delta 13), pack-reused 12229
# Receiving objects: 100% (12264/12264), 12.01 MiB | 7.09 MiB/s, done.
# Resolving deltas: 100% (8488/8488), done.

# %%
# !mkdir data
# Out:
# mkdir: cannot create directory ‘data’: File exists

# %%
cd '/content/drive/MyDrive/pbl_ai/data'
# Out:
# /content/drive/MyDrive/pbl_ai/data

# %%
# !unzip /content/drive/MyDrive/pbl_ai/data/cat-and-dog.v1i.yolov5pytorch.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: train/images/Cats_Test3092_png.rf.787662eadba92c92ae863a46631e03c7.jpg
#  extracting: train/images/Cats_Test3093_png.rf.f3c277737f29983b96422fbddaf4f3b5.jpg
#  extracting: train/images/Cats_Test3095_png.rf.0c10c03191ac892b113bfe0d3b32ca8f.jpg
#  extracting: train/images/Cats_Test3096_png.rf.29ea1cda7e6bd4614f9529e67be7d440.jpg
#  extracting: train/images/Cats_Test3097_png.rf.2858fe14439bbcfeba62e5655bd18c95.jpg
#  extracting: train/images/Cats_Test3098_png.rf.67936efe2db07e1daf5a8eab42eee278.jpg
#  extracting: train/images/Cats_Test3099_png.rf.607e0564dce93098150bd50fb1c6c5e4.jpg
#  extracting: train/images/Cats_Test309_png.rf.f8baee1fa5290bb7585ad64d0c70490c.jpg
#  extracting: train/images/Cats_Test30_png.rf.1037e7f512bb60aebfcc8526a5fdfd2f.jpg
#  extracting: train/images/Cats_Test3100_png.rf.fb68027900a475dd8f623726038460cf.jpg
#  extracting: train/images/Cats_Test3101_png.rf.bcb9b6c8169430c3126ac830124ca25e.jpg
# ...

# %%
# !mkdir 'data/images' 'data/labels'

# %%
# !mkdir 'data/images/train' 'data/labels/train' 'data/images/valid' 'data/labels/valid'
# Out:
# mkdir: cannot create directory ‘data/images/train’: File exists
# mkdir: cannot create directory ‘data/labels/train’: File exists
# mkdir: cannot create directory ‘data/images/valid’: File exists
# mkdir: cannot create directory ‘data/labels/valid’: File exists

# %%
cd '/content/drive/MyDrive/pbl_ai/yolov5'
# Out:
# /content/drive/MyDrive/pbl_ai/yolov5

# %%
import os

# %%
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow

# %%
os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/pbl_ai/data"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="IaRPg26EoZA9XCY9VeFl")
project = rf.workspace().project("cat-and-dog-nbiq4")
dataset = project.version("1").download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/drive/MyDrive/pbl_ai/data/cat-and-dog-1 in yolov5pytorch:: 100%|██████████| 7358/7358 [32:13<00:00,  3.81it/s]

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/pbl_ai/data/cat-and-dog-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 v6.1-253-g75bbaa8 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
ls

# %%
#export your model's weights for future use
from google.colab import files
files.download('./runs/train/exp6/weights/best.pt')

# %%
# !python export.py --weights ./runs/train/exp6/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['./runs/train/exp6/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v6.1-253-g75bbaa8 Python-3.7.13 torch-1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/exp6/weights/best.pt with output shape (1, 25200, 7) (13.7 MB)
#
# TorchScript: starting export with torch 1.11.0+cu113...
# TorchScript: export success, saved as runs/train/exp6/weights/best.torchscript (27.2 MB)
#
# ONNX: starting export with onnx 1.11.0...
# ONNX: export success, saved as runs/train/exp6/weights/best.onnx (27.2 MB)
#
# Export complete (5.79s)
# ...
